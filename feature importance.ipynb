# %% [markdown]
# ## ファクター重要度

# %%
import matome_pre
import time
import datetime as dt
import os
import pytz
import pickle
from optuna.integration import lightgbm as lgb
import matplotlib.pyplot as plt

import pandas as pd
from bs4 import BeautifulSoup
from statistics import mean
import glob




#####################################
save_dir = "./model"
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)

now_datetime = dt.datetime.now(pytz.timezone('Asia/Tokyo'))
now_datetime = str(now_datetime)
now_datetime = now_datetime[2:10].replace("-","")
file = save_dir+'/全国_lightbgm(gbdt_perfect_discate_prize_rank).pkl'

model1 = pickle.load(open(file, 'rb'))
#####################################
    
lgb.plot_importance(model1,max_num_features = 120,figsize=(10,25))
# Out:
# C:\Users\c1720\anaconda3\envs\awesome\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 20140 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\c1720\anaconda3\envs\awesome\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 37117 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\c1720\anaconda3\envs\awesome\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 20140 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\c1720\anaconda3\envs\awesome\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 37117 missing from current font.
#   font.set_text(s, 0, flags=flags)
